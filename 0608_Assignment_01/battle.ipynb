# %%
from pokemon_gym import enter_gym
from example_team import PokemonTeam

# %%
my_team = PokemonTeam()

# %%
enter_gym(my_team)
# Out:
# ****************************************************************
# *           WELCOME TO THE POKEMON TRAINING GYM                 *
# ****************************************************************
#
# ...
#   STEP 1 - CHECKING YOUR TEAM
# ...
#
#   [X] FATAL PROBLEMS - the tournament can't run until these are fixed:
#       - Pokemon 'Aquarump' is missing the ._max_hp attribute.
#       - Pokemon 'Aquarump' is missing the .hp attribute.
#       - Pokemon 'Aquarump' is missing the .defense attribute.
#       - Pokemon 'Aquarump' is missing the .power attribute.
#       - Pokemon 'Aquarump'.attacks must be a non-empty dictionary.
#
#   Fix the fatal problems above and run the gym again. Good luck!
